# %%
## Importing V-Dem Dataset 
import pandas as pd 

df = pd.read_csv("/Users/matthewrisley/Desktop/Senior Thesis /V-Dem-CY-FullOthers-v14_csv_YyKfizl/V-Dem-CY-Full+Others-v14.csv")
# Out:
# /var/folders/h1/4jp4f8ws0fs6b8cs88b3nrhh0000gn/T/ipykernel_18557/2229541668.py:4: DtypeWarning: Columns (364,365,366,399,415,804,836,837,924,1240,1257,1486,3094,3168,3169,3341,3342,3344,3345,3347,3350,3352) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/matthewrisley/Desktop/Senior Thesis /V-Dem-CY-FullOthers-v14_csv_YyKfizl/V-Dem-CY-Full+Others-v14.csv")

# %%
df.head()
# Out:
#   country_name country_text_id  country_id  year historical_date  project  \
# 0       Mexico             MEX           3  1789      1789-12-31        1
# 1       Mexico             MEX           3  1790      1790-12-31        1
# 2       Mexico             MEX           3  1791      1791-12-31        1
# 3       Mexico             MEX           3  1792      1792-12-31        1
# 4       Mexico             MEX           3  1793      1793-12-31        1
#
#    historical                  histname  codingstart  codingend  ...  \
# 0           1  Viceroyalty of New Spain         1789       2023  ...
# 1           1  Viceroyalty of New Spain         1789       2023  ...
# 2           1  Viceroyalty of New Spain         1789       2023  ...
# 3           1  Viceroyalty of New Spain         1789       2023  ...
# 4           1  Viceroyalty of New Spain         1789       2023  ...
#
#    e_mipopula  e_miurbani  e_pefeliex  e_wb_pop  e_pechmor  e_miinteco  \
# ...

# %%
#Keeping only relevant columns
columns_to_keep = [ 'COWcode', 'year', 'e_area','e_gdppc', 'e_wb_pop']
elec_data = df[columns_to_keep]
elec_data.rename(columns={'COWcode': 'ccode'}, inplace=True)
# Out:
# /var/folders/h1/4jp4f8ws0fs6b8cs88b3nrhh0000gn/T/ipykernel_18557/1737811286.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elec_data.rename(columns={'COWcode': 'ccode'}, inplace=True)

# %%
#Dropping years before 1980
elec_data = elec_data[(elec_data.year >= 1980)& (elec_data.year <=2020)]
elec_data.tail(50)
# Out:
#        ccode  year     e_area  e_gdppc   e_wb_pop
# 26155  310.0  2012  92949.133   20.169  9920362.0
# 26156  310.0  2013  92949.133   20.744  9893082.0
# 26157  310.0  2014  92949.133   21.432  9866468.0
# 26158  310.0  2015  92949.133   22.275  9843028.0
# 26159  310.0  2016  92949.133   23.006  9814023.0
# 26160  310.0  2017  92949.133   24.072  9787966.0
# 26161  310.0  2018  92949.133   25.211  9775564.0
# 26162  310.0  2019  92949.133   25.834  9771141.0
# 26163  310.0  2020  92949.133      NaN  9750149.0
# 26291    NaN  1980        NaN      NaN        NaN
# 26292    NaN  1981        NaN      NaN        NaN
# 26293    NaN  1982        NaN      NaN        NaN
# 26294    NaN  1983        NaN      NaN        NaN
# 26295    NaN  1984        NaN      NaN        NaN
# 26296    NaN  1985        NaN      NaN        NaN
# 26297    NaN  1986        NaN      NaN        NaN
# 26298    NaN  1987        NaN      NaN        NaN
# 26299    NaN  1988        NaN      NaN        NaN
# ...

# %%
elec_data.to_csv('/Users/matthewrisley/Desktop/Senior Thesis /Cleaning Dataframes/testingVdemControls.csv', index=False)
